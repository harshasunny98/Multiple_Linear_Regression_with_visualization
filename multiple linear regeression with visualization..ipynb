# %% [markdown]
# # Multiple Linear Regression
# ###                           - with 3D visualization
#
# ## [where the length of a fish is predicted based on temperature of water and age of Fish.]

# %%
#reading data from Fish.csv
from numpy import *
data=genfromtxt("Fish.csv",delimiter=",")
print(data)
# Out:
# [[   nan    nan    nan]
#  [   14.    25.   620.]
#  [   28.    25.  1315.]
#  [   41.    25.  2120.]
#  [   55.    25.  2600.]
#  [   69.    25.  3110.]
#  [   83.    25.  3535.]
#  [   97.    25.  3935.]
#  [  111.    25.  4465.]
#  [  125.    25.  4530.]
#  [  139.    25.  4570.]
#  [  153.    25.  4600.]
#  [   14.    27.   625.]
#  [   28.    27.  1215.]
#  [   41.    27.  2110.]
#  [   55.    27.  2805.]
#  [   69.    27.  3255.]
#  [   83.    27.  4015.]
#  [   97.    27.  4315.]
#  [  111.    27.  4495.]
#  [  125.    27.  4535.]
#  [  139.    27.  4600.]
#  [  153.    27.  4600.]
#  [   14.    29.   590.]
#  [   28.    29.  1305.]
#  [   41.    29.  2140.]
#  [   55.    29.  2890.]
#  [   69.    29.  3920.]
#  [   83.    29.  3920.]
#  [   97.    29.  4515.]
#  [  111.    29.  4520.]
#  [  125.    29.  4525.]
#  [  139.    29.  4565.]
#  [  153.    29.  4566.]
#  [   14.    31.   590.]
#  [   28.    31.  1205.]
#  [   41.    31.  1915.]
#  [   55.    31.  2140.]
#  [   69.    31.  2710.]
#  [   83.    31.  3020.]
#  [   97.    31.  3030.]
#  [  111.    31.  3040.]
#  [  125.    31.  3180.]
#  [  139.    31.  3257.]
#  [  153.    31.  3214.]]

# %%
#deleating first row
data=delete(data,(0),axis=0)
#print(data)

# %%
#storing y coordinates and x coordinates into another array list
y_mat=array(data[:,len(data[0])-1])
ex_mat2=array(data[:,len(data[0])-2])
ex_mat1=array(data[:,len(data[0])-3])
#print(ex_mat1)
#print(ex_mat2)

# %%
#replacing all values of y with 1 in data and storing in a_mat.
a_mat=data
a_mat[:,len(a_mat[0])-1]=1

# %%
print(a_mat)
# Out:
# [[  14.   25.    1.]
#  [  28.   25.    1.]
#  [  41.   25.    1.]
#  [  55.   25.    1.]
#  [  69.   25.    1.]
#  [  83.   25.    1.]
#  [  97.   25.    1.]
#  [ 111.   25.    1.]
#  [ 125.   25.    1.]
#  [ 139.   25.    1.]
#  [ 153.   25.    1.]
#  [  14.   27.    1.]
#  [  28.   27.    1.]
#  [  41.   27.    1.]
#  [  55.   27.    1.]
#  [  69.   27.    1.]
#  [  83.   27.    1.]
#  [  97.   27.    1.]
#  [ 111.   27.    1.]
#  [ 125.   27.    1.]
#  [ 139.   27.    1.]
#  [ 153.   27.    1.]
#  [  14.   29.    1.]
#  [  28.   29.    1.]
#  [  41.   29.    1.]
#  [  55.   29.    1.]
#  [  69.   29.    1.]
#  [  83.   29.    1.]
#  [  97.   29.    1.]
#  [ 111.   29.    1.]
#  [ 125.   29.    1.]
#  [ 139.   29.    1.]
#  [ 153.   29.    1.]
#  [  14.   31.    1.]
#  [  28.   31.    1.]
#  [  41.   31.    1.]
#  [  55.   31.    1.]
#  [  69.   31.    1.]
#  [  83.   31.    1.]
#  [  97.   31.    1.]
#  [ 111.   31.    1.]
#  [ 125.   31.    1.]
#  [ 139.   31.    1.]
#  [ 153.   31.    1.]]

# %%
y_mat.resize(len(a_mat),1)
print(y_mat)
# Out:
# [[  620.]
#  [ 1315.]
#  [ 2120.]
#  [ 2600.]
#  [ 3110.]
#  [ 3535.]
#  [ 3935.]
#  [ 4465.]
#  [ 4530.]
#  [ 4570.]
#  [ 4600.]
#  [  625.]
#  [ 1215.]
#  [ 2110.]
#  [ 2805.]
#  [ 3255.]
#  [ 4015.]
#  [ 4315.]
#  [ 4495.]
#  [ 4535.]
#  [ 4600.]
#  [ 4600.]
#  [  590.]
#  [ 1305.]
#  [ 2140.]
#  [ 2890.]
#  [ 3920.]
#  [ 3920.]
#  [ 4515.]
#  [ 4520.]
#  [ 4525.]
#  [ 4565.]
#  [ 4566.]
#  [  590.]
#  [ 1205.]
#  [ 1915.]
#  [ 2140.]
#  [ 2710.]
#  [ 3020.]
#  [ 3030.]
#  [ 3040.]
#  [ 3180.]
#  [ 3257.]
#  [ 3214.]]

# %% [markdown]
# ## caliculating intercepts inorder to keep error as low as possible

# %%
#caliculating unkown b0,b1,b2 by using lstsq
x_mat=matrix(linalg.lstsq(a_mat,y_mat)[0])
x_mat.resize(len(a_mat[0]),1)
y_pred=dot(a_mat,x_mat)
print(x_mat)
print(y_pred)
# Out:
# [[   26.24068177]
#  [ -106.41363636]
#  [ 3904.26601675]]
# [[ 1611.29465238]
#  [ 1978.6641971 ]
#  [ 2319.79306006]
#  [ 2687.16260478]
#  [ 3054.5321495 ]
#  [ 3421.90169422]
#  [ 3789.27123895]
#  [ 4156.64078367]
#  [ 4524.01032839]
#  [ 4891.37987311]
#  [ 5258.74941783]
#  [ 1398.46737966]
#  [ 1765.83692438]
#  [ 2106.96578733]
#  [ 2474.33533205]
#  [ 2841.70487678]
#  [ 3209.0744215 ]
#  [ 3576.44396622]
#  [ 3943.81351094]
#  [ 4311.18305566]
#  [ 4678.55260038]
#  [ 5045.9221451 ]
#  [ 1185.64010693]
#  [ 1553.00965165]
#  [ 1894.13851461]
#  [ 2261.50805933]
#  [ 2628.87760405]
#  [ 2996.24714877]
#  [ 3363.61669349]
#  [ 3730.98623821]
#  [ 4098.35578293]
#  [ 4465.72532766]
#  [ 4833.09487238]
#  [  972.8128342 ]
#  [ 1340.18237892]
#  [ 1681.31124188]
#  [ 2048.6807866 ]
#  [ 2416.05033132]
#  [ 2783.41987604]
#  [ 3150.78942076]
#  [ 3518.15896549]
#  [ 3885.52851021]
#  [ 4252.89805493]
#  [ 4620.26759965]]

# %%
#caliculating error
diff=(y_mat-y_pred)
error=sum(multiply(diff,diff))/len(a_mat)

# %%
print("b0=",float(y_pred[len(y_pred)-1]),sep="")
for i in range(len(x_mat)-1):
    print("b",i+1,"=",float(y_pred[i]),sep="")
print("Error:",error)
# Out:
# b0=4620.267599650338
# b1=1611.2946523824603
# b2=1978.6641971040124
# Error: 335451.769187

# %%
ex_mat1.resize(len(a_mat),1)
ex_mat2.resize(len(a_mat),1)
#print(y_mat)
# Out:
# [[  620.]
#  [ 1315.]
#  [ 2120.]
#  [ 2600.]
#  [ 3110.]
#  [ 3535.]
#  [ 3935.]
#  [ 4465.]
#  [ 4530.]
#  [ 4570.]
#  [ 4600.]
#  [  625.]
#  [ 1215.]
#  [ 2110.]
#  [ 2805.]
#  [ 3255.]
#  [ 4015.]
#  [ 4315.]
#  [ 4495.]
#  [ 4535.]
#  [ 4600.]
#  [ 4600.]
#  [  590.]
#  [ 1305.]
#  [ 2140.]
#  [ 2890.]
#  [ 3920.]
#  [ 3920.]
#  [ 4515.]
#  [ 4520.]
#  [ 4525.]
#  [ 4565.]
#  [ 4566.]
#  [  590.]
#  [ 1205.]
#  [ 1915.]
#  [ 2140.]
#  [ 2710.]
#  [ 3020.]
#  [ 3030.]
#  [ 3040.]
#  [ 3180.]
#  [ 3257.]
#  [ 3214.]]

# %%
b0=float(x_mat[0])
b1=float(x_mat[1])
b2=float(x_mat[2])
print(b0,b1,b2)
# Out:
# 26.24068176582516 -106.41363636363663 3904.266016751824

# %% [markdown]
# ## Visualization

# %%
from mpl_toolkits.mplot3d import Axes3D
xx1, xx2 = np.meshgrid(np.linspace(min(ex_mat1),max(ex_mat1), 100), np.linspace(min(ex_mat2), max(ex_mat2), 100))
# plot the hyperplane by evaluating the parameters on the grid
Z = b0 * xx1 + b1 * xx2 + b2

# create matplotlib 3d axes
fig = plt.figure(figsize=(12, 8))
ax = Axes3D(fig, azim=-115, elev=15)

ax.set_xlabel('Age of Fish')
ax.set_ylabel('Temperature of Water')
ax.set_zlabel('Length of Fish')

# plot predicted plane
surf = ax.plot_surface(xx1, xx2, Z, cmap=plt.cm.RdBu_r, alpha=0.6, linewidth=0)
# plot actual data 
ax.scatter(ex_mat1, ex_mat2, y_mat,'*', color='red', alpha=1.0, facecolor='orange')

# %%
plt.show()
